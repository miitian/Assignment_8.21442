# %%
import pandas as pd
import sqlite3 as sql

# %%
adult_names  = pd.read_table('adult_names.txt').iloc[91:]
adult_names.columns = ['name']
column_name = adult_names['name'].str.split(':', expand= True)[0]
columns =  column_name.iloc[1:] 
columns = columns.append(column_name.iloc[0:1], ignore_index=True)
columns
# Out:
# 0                age
# 1          workclass
# 2             fnlwgt
# 3          education
# 4      education-num
# 5     marital-status
# 6         occupation
# 7       relationship
# 8               race
# 9                sex
# 10      capital-gain
# 11      capital-loss
# 12    hours-per-week
# 13    native-country
# 14      >50K, <=50K.
# Name: 0, dtype: object

# %%
adult = pd.read_csv('adult_data.csv', header= None)
adult.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3   United-States   <=50K
# 4            Cuba   <=50K

# %%
adult.columns = [col for col in columns]
adult.head()
#adult.describe()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country >50K, <=50K.
# 0          2174             0              40   United-States        <=50K
# 1             0             0              13   United-States        <=50K
# 2             0             0              40   United-States        <=50K
# 3             0             0              40   United-States        <=50K
# 4             0             0              40            Cuba        <=50K

# %% [markdown]
# ### 1. Create an sqlalchemy engine using a sample from the data set

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///sqldb.db')
#engine.execute('DROP table adult')
adult.to_sql('adult', con=engine, if_exists='replace', index_label='id')

# %%
rows = engine.execute("SELECT sql FROM sqlite_master WHERE name like '%adult%' ")
for row in rows:
    print(row, '\n')
# Out:
# ('CREATE TABLE "adult.head()" (\n\t"index" BIGINT, \n\tage BIGINT, \n\tworkclass TEXT, \n\tfnlwgt BIGINT, \n\teducation TEXT, \n\t"education-num" BIGIN ... (90 characters truncated) ... n\tsex TEXT, \n\t"capital-gain" BIGINT, \n\t"capital-loss" BIGINT, \n\t"hours-per-week" BIGINT, \n\t"native-country" TEXT, \n\t">50K, <=50K." TEXT\n)',)
#
# ('CREATE INDEX "ix_adult.head()_index" ON "adult.head()" ("index")',)
#
# ('CREATE TABLE adult (\n\tid BIGINT, \n\tage BIGINT, \n\tworkclass TEXT, \n\tfnlwgt BIGINT, \n\teducation TEXT, \n\t"education-num" BIGINT, \n\t"marita ... (76 characters truncated) ... n\tsex TEXT, \n\t"capital-gain" BIGINT, \n\t"capital-loss" BIGINT, \n\t"hours-per-week" BIGINT, \n\t"native-country" TEXT, \n\t">50K, <=50K." TEXT\n)',)
#
# ('CREATE INDEX ix_adult_id ON adult (id)',)

# %% [markdown]
# ### write select queries

# %%
rows = engine.execute('''select * from adult limit 5''')

for row in rows:
    print(row, '\n')
# Out:
# (0, 39, ' State-gov', 77516, ' Bachelors', 13, ' Never-married', ' Adm-clerical', ' Not-in-family', ' White', ' Male', 2174, 0, 40, ' United-States', ' <=50K')
#
# (1, 50, ' Self-emp-not-inc', 83311, ' Bachelors', 13, ' Married-civ-spouse', ' Exec-managerial', ' Husband', ' White', ' Male', 0, 0, 13, ' United-States', ' <=50K')
#
# (2, 38, ' Private', 215646, ' HS-grad', 9, ' Divorced', ' Handlers-cleaners', ' Not-in-family', ' White', ' Male', 0, 0, 40, ' United-States', ' <=50K')
#
# (3, 53, ' Private', 234721, ' 11th', 7, ' Married-civ-spouse', ' Handlers-cleaners', ' Husband', ' Black', ' Male', 0, 0, 40, ' United-States', ' <=50K')
#
# (4, 28, ' Private', 338409, ' Bachelors', 13, ' Married-civ-spouse', ' Prof-specialty', ' Wife', ' Black', ' Female', 0, 0, 40, ' Cuba', ' <=50K')

# %%
rows = engine.execute('''select age, workclass, "marital-status" from adult limit 5''')

for row in rows:
    print(row, '\n')
# Out:
# (39, ' State-gov', ' Never-married')
#
# (50, ' Self-emp-not-inc', ' Married-civ-spouse')
#
# (38, ' Private', ' Divorced')
#
# (53, ' Private', ' Married-civ-spouse')
#
# (28, ' Private', ' Married-civ-spouse')

# %% [markdown]
# ### 2. Write two basic update queries

# %%
engine.execute('''update adult set "native-country" ='USA' where "native-country"=' United-States' ''')

# %%
engine.execute('''update adult set workclass ='Private' where workclass=' Private' ''')

# %% [markdown]
# ### 3. Write two delete queries

# %%
engine.execute('''delete from adult where id=0 ''')

# %%
engine.execute('''delete from adult where "hours-per-week"<20 ''')

# %% [markdown]
# ### 4. Write two filter queries

# %%
rows = engine.execute('''select age, workclass, "marital-status" from adult where id>5 limit 5''')

for row in rows:
    print(row, '\n')
# Out:
# (52, ' Self-emp-not-inc', ' Married-civ-spouse')
#
# (31, 'Private', ' Never-married')
#
# (42, 'Private', ' Married-civ-spouse')
#
# (37, 'Private', ' Married-civ-spouse')
#
# (30, ' State-gov', ' Married-civ-spouse')

# %%
rows = engine.execute('''select age, workclass, "marital-status" from adult where age>50 and "marital-status"=' Married-civ-spouse' limit 5''')

for row in rows:
    print(row, '\n')
# Out:
# (53, 'Private', ' Married-civ-spouse')
#
# (52, ' Self-emp-not-inc', ' Married-civ-spouse')
#
# (56, ' Local-gov', ' Married-civ-spouse')
#
# (54, ' ?', ' Married-civ-spouse')
#
# (53, ' Self-emp-not-inc', ' Married-civ-spouse')

# %% [markdown]
# ### 5. Write two function queries

# %%
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind=engine)
Session.configure(bind=engine) 
session = Session()
adult.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
from sqlalchemy import func
from sqlalchemy import text

# %%
from sqlalchemy import (Table, Column, String, Integer, MetaData, select, func)

metadata = MetaData()

adult = Table('adult', metadata,
              Column('age', Integer),
              Column('workclass', String),
              Column('education', String),
              Column('occupation', String),
             
)

# %%
for t in metadata.sorted_tables:
    print(t.name)
# Out:
# adult

# %%
#adult.columns.age
#session.query(func.count(adult.columns.age)).all()
session.query(func.count(adult.columns.workclass)).all()
# Out:
# [(30856)]

# %%
session.query(adult.columns.age, func.count(adult.columns.age)).group_by(adult.columns.age).all()
# Out:
# [(17, 228),
#  (18, 413),
#  (19, 601),
#  (20, 657),
#  (21, 641),
#  (22, 697),
#  (23, 826),
#  (24, 768),
#  (25, 817),
#  (26, 761),
#  (27, 820),
#  (28, 844),
#  (29, 798),
#  (30, 839),
#  (31, 874),
#  (32, 810),
#  (33, 862),
#  (34, 864),
#  (35, 863),
#  (36, 882),
#  (37, 844),
#  (38, 814),
#  (39, 799),
#  (40, 781),
#  (41, 790),
#  (42, 767),
#  (43, 759),
#  (44, 709),
#  (45, 716),
#  (46, 727),
#  (47, 694),
#  (48, 531),
#  (49, 569),
#  (50, 587),
#  (51, 585),
#  (52, 469),
#  (53, 461),
#  (54, 407),
#  (55, 407),
#  (56, 358),
#  (57, 344),
#  (58, 351),
#  (59, 343),
#  (60, 297),
#  (61, 279),
#  (62, 237),
#  (63, 205),
#  (64, 171),
#  (65, 156),
#  (66, 125),
#  (67, 113),
#  (68, 97),
#  (69, 80),
#  (70, 68),
#  (71, 46),
#  (72, 45),
#  (73, 41),
#  (74, 29),
#  (75, 29),
#  (76, 28),
#  (77, 17),
#  (78, 14),
#  (79, 17),
#  (80, 16),
#  (81, 11),
#  (82, 6),
#  (83, 5),
#  (84, 5),
#  (85, 2),
#  (86, 1),
#  (88, 3),
#  (90, 36)]

# %%
session.query(adult).filter(adult.c.age == 39).all()
# Out:
# [(39, 'Private', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' Some-college', ' Craft-repair'),
#  (39, ' Federal-gov', ' Assoc-acdm', ' Exec-managerial'),
#  (39, ' ?', ' Masters', ' ?'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Sales'),
#  (39, 'Private', ' HS-grad', ' Other-service'),
#  (39, ' Local-gov', ' 12th', ' Tech-support'),
#  (39, 'Private', ' HS-grad', ' Handlers-cleaners'),
#  (39, 'Private', ' HS-grad', ' Handlers-cleaners'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' Bachelors', ' Craft-repair'),
#  (39, 'Private', ' Some-college', ' Farming-fishing'),
#  (39, 'Private', ' HS-grad', ' Transport-moving'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, ' Self-emp-inc', ' Bachelors', ' Exec-managerial'),
#  (39, ' Self-emp-inc', ' HS-grad', ' Exec-managerial'),
#  (39, ' Self-emp-inc', ' 9th', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Transport-moving'),
#  (39, 'Private', ' HS-grad', ' Transport-moving'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Craft-repair'),
#  (39, ' Local-gov', ' Assoc-acdm', ' Craft-repair'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' 9th', ' Other-service'),
#  (39, 'Private', ' HS-grad', ' Transport-moving'),
#  (39, ' Local-gov', ' HS-grad', ' Protective-serv'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' 10th', ' Craft-repair'),
#  (39, 'Private', ' 11th', ' Other-service'),
#  (39, ' ?', ' HS-grad', ' ?'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' Masters', ' Exec-managerial'),
#  (39, 'Private', ' Some-college', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' 1st-4th', ' Craft-repair'),
#  (39, 'Private', ' Some-college', ' Farming-fishing'),
#  (39, ' Local-gov', ' 10th', ' Handlers-cleaners'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, 'Private', ' Masters', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, ' ?', ' Some-college', ' ?'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, ' ?', ' HS-grad', ' ?'),
#  (39, ' Local-gov', ' Masters', ' Prof-specialty'),
#  (39, ' State-gov', ' HS-grad', ' Other-service'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Sales'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Sales'),
#  (39, ' Self-emp-inc', ' Bachelors', ' Sales'),
#  (39, 'Private', ' Assoc-voc', ' Adm-clerical'),
#  (39, 'Private', ' Masters', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' Some-college', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Sales'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, ' Local-gov', ' 11th', ' Transport-moving'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, ' Self-emp-inc', ' Assoc-acdm', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' 10th', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' Assoc-acdm', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' 11th', ' Machine-op-inspct'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, ' Self-emp-not-inc', ' Some-college', ' Craft-repair'),
#  (39, ' Local-gov', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' Some-college', ' Exec-managerial'),
#  (39, ' Local-gov', ' Assoc-acdm', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Machine-op-inspct'),
#  (39, 'Private', ' Masters', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Exec-managerial'),
#  (39, ' Self-emp-not-inc', ' Assoc-voc', ' Farming-fishing'),
#  (39, ' Local-gov', ' Bachelors', ' Adm-clerical'),
#  (39, ' Local-gov', ' Some-college', ' Exec-managerial'),
#  (39, 'Private', ' 12th', ' Sales'),
#  (39, ' ?', ' Preschool', ' ?'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, 'Private', ' HS-grad', ' Sales'),
#  (39, 'Private', ' Assoc-acdm', ' Craft-repair'),
#  (39, 'Private', ' Bachelors', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Transport-moving'),
#  (39, 'Private', ' HS-grad', ' Sales'),
#  (39, 'Private', ' Assoc-acdm', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Tech-support'),
#  (39, 'Private', ' Some-college', ' Craft-repair'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Handlers-cleaners'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Sales'),
#  (39, ' Self-emp-not-inc', ' Prof-school', ' Prof-specialty'),
#  (39, ' Local-gov', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Exec-managerial'),
#  (39, ' Federal-gov', ' Prof-school', ' Prof-specialty'),
#  (39, 'Private', ' Assoc-acdm', ' Transport-moving'),
#  (39, 'Private', ' Some-college', ' Sales'),
#  (39, ' Self-emp-not-inc', ' Some-college', ' Craft-repair'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, ' Self-emp-not-inc', ' Bachelors', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Sales'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, ' Self-emp-inc', ' Prof-school', ' Prof-specialty'),
#  (39, 'Private', ' Masters', ' Transport-moving'),
#  (39, ' State-gov', ' HS-grad', ' Other-service'),
#  (39, ' Self-emp-not-inc', ' 9th', ' Craft-repair'),
#  (39, ' Federal-gov', ' Bachelors', ' Protective-serv'),
#  (39, ' State-gov', ' Some-college', ' Protective-serv'),
#  (39, ' Local-gov', ' HS-grad', ' Protective-serv'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Handlers-cleaners'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, ' Local-gov', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' Some-college', ' Other-service'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, ' Self-emp-inc', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' 11th', ' Craft-repair'),
#  (39, ' Local-gov', ' Assoc-voc', ' Protective-serv'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, ' Self-emp-not-inc', ' Prof-school', ' Prof-specialty'),
#  (39, ' Self-emp-inc', ' Some-college', ' Farming-fishing'),
#  (39, 'Private', ' Some-college', ' Sales'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' Some-college', ' Sales'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Sales'),
#  (39, 'Private', ' HS-grad', ' Other-service'),
#  (39, 'Private', ' Masters', ' Exec-managerial'),
#  (39, ' Self-emp-inc', ' Assoc-acdm', ' Exec-managerial'),
#  (39, 'Private', ' Assoc-acdm', ' Sales'),
#  (39, ' Self-emp-inc', ' Bachelors', ' Sales'),
#  (39, ' State-gov', ' Some-college', ' Exec-managerial'),
#  (39, 'Private', ' Some-college', ' Transport-moving'),
#  (39, 'Private', ' Masters', ' Sales'),
#  (39, 'Private', ' Some-college', ' Exec-managerial'),
#  (39, ' Local-gov', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, 'Private', ' Masters', ' Craft-repair'),
#  (39, 'Private', ' Bachelors', ' Tech-support'),
#  (39, 'Private', ' Masters', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Farming-fishing'),
#  (39, ' Local-gov', ' HS-grad', ' Protective-serv'),
#  (39, ' Local-gov', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' Masters', ' Exec-managerial'),
#  (39, ' Self-emp-not-inc', ' Some-college', ' Farming-fishing'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' Assoc-acdm', ' Craft-repair'),
#  (39, ' Local-gov', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' Prof-school', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' Some-college', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Other-service'),
#  (39, 'Private', ' Prof-school', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Handlers-cleaners'),
#  (39, ' State-gov', ' Bachelors', ' Protective-serv'),
#  (39, ' State-gov', ' Bachelors', ' Exec-managerial'),
#  (39, ' Local-gov', ' HS-grad', ' Protective-serv'),
#  (39, 'Private', ' Some-college', ' Other-service'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, ' Local-gov', ' 11th', ' Other-service'),
#  (39, 'Private', ' Bachelors', ' Craft-repair'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, ' Local-gov', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Sales'),
#  (39, 'Private', ' 11th', ' Other-service'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' Doctorate', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Other-service'),
#  (39, ' Self-emp-inc', ' Bachelors', ' Exec-managerial'),
#  (39, ' Federal-gov', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Sales'),
#  (39, 'Private', ' Masters', ' Exec-managerial'),
#  (39, ' Local-gov', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, ' Federal-gov', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, ' Self-emp-not-inc', ' Masters', ' Prof-specialty'),
#  (39, ' Local-gov', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' Prof-school', ' Exec-managerial'),
#  (39, ' State-gov', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Tech-support'),
#  (39, 'Private', ' HS-grad', ' Transport-moving'),
#  (39, 'Private', ' Some-college', ' Sales'),
#  (39, 'Private', ' HS-grad', ' Handlers-cleaners'),
#  (39, 'Private', ' HS-grad', ' Other-service'),
#  (39, 'Private', ' Doctorate', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Transport-moving'),
#  (39, 'Private', ' Some-college', ' Machine-op-inspct'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' Assoc-voc', ' Adm-clerical'),
#  (39, 'Private', ' Some-college', ' Handlers-cleaners'),
#  (39, ' Self-emp-inc', ' Bachelors', ' Exec-managerial'),
#  (39, ' Self-emp-not-inc', ' Assoc-acdm', ' Adm-clerical'),
#  (39, ' State-gov', ' Doctorate', ' Prof-specialty'),
#  (39, ' Federal-gov', ' Some-college', ' Handlers-cleaners'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' 10th', ' Other-service'),
#  (39, 'Private', ' Some-college', ' Tech-support'),
#  (39, ' Self-emp-inc', ' HS-grad', ' Craft-repair'),
#  (39, ' Self-emp-inc', ' Bachelors', ' Exec-managerial'),
#  (39, ' Local-gov', ' Masters', ' Prof-specialty'),
#  (39, ' Local-gov', ' Some-college', ' Prof-specialty'),
#  (39, 'Private', ' 9th', ' Transport-moving'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Tech-support'),
#  (39, 'Private', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' Masters', ' Sales'),
#  (39, 'Private', ' Some-college', ' Sales'),
#  (39, ' Self-emp-inc', ' Some-college', ' Prof-specialty'),
#  (39, ' State-gov', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' 10th', ' Machine-op-inspct'),
#  (39, 'Private', ' Some-college', ' Sales'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Craft-repair'),
#  (39, ' Self-emp-not-inc', ' Some-college', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Other-service'),
#  (39, 'Private', ' Bachelors', ' Tech-support'),
#  (39, ' Self-emp-not-inc', ' Bachelors', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' 5th-6th', ' Sales'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' Assoc-voc', ' Exec-managerial'),
#  (39, 'Private', ' Masters', ' Exec-managerial'),
#  (39, ' Federal-gov', ' Bachelors', ' Adm-clerical'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, ' Local-gov', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Sales'),
#  (39, ' Local-gov', ' 11th', ' Adm-clerical'),
#  (39, ' Local-gov', ' Bachelors', ' Craft-repair'),
#  (39, 'Private', ' Masters', ' Prof-specialty'),
#  (39, ' ?', ' Bachelors', ' ?'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, ' Federal-gov', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' Bachelors', ' Adm-clerical'),
#  (39, 'Private', ' Assoc-acdm', ' Adm-clerical'),
#  (39, ' State-gov', ' Assoc-acdm', ' Protective-serv'),
#  (39, ' State-gov', ' HS-grad', ' Protective-serv'),
#  (39, 'Private', ' Assoc-voc', ' Machine-op-inspct'),
#  (39, 'Private', ' HS-grad', ' Farming-fishing'),
#  (39, ' Federal-gov', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, ' Self-emp-inc', ' Masters', ' Exec-managerial'),
#  (39, ' Self-emp-not-inc', ' Some-college', ' Craft-repair'),
#  (39, 'Private', ' Some-college', ' Craft-repair'),
#  (39, 'Private', ' 5th-6th', ' Handlers-cleaners'),
#  (39, ' State-gov', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Other-service'),
#  (39, 'Private', ' Some-college', ' Sales'),
#  (39, 'Private', ' Some-college', ' Craft-repair'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' HS-grad', ' Priv-house-serv'),
#  (39, 'Private', ' HS-grad', ' Other-service'),
#  (39, 'Private', ' HS-grad', ' Transport-moving'),
#  (39, 'Private', ' Assoc-voc', ' Adm-clerical'),
#  (39, 'Private', ' Masters', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Sales'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, 'Private', ' Masters', ' Prof-specialty'),
#  (39, ' State-gov', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' Some-college', ' Sales'),
#  (39, 'Private', ' HS-grad', ' Sales'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, ' Federal-gov', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' Some-college', ' Farming-fishing'),
#  (39, ' Local-gov', ' 12th', ' Transport-moving'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' Assoc-voc', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, ' Local-gov', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, ' Federal-gov', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Other-service'),
#  (39, 'Private', ' Bachelors', ' Craft-repair'),
#  (39, 'Private', ' Some-college', ' Sales'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, ' Self-emp-not-inc', ' Bachelors', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Farming-fishing'),
#  (39, ' Federal-gov', ' HS-grad', ' Adm-clerical'),
#  (39, ' Self-emp-inc', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' Assoc-voc', ' Handlers-cleaners'),
#  (39, 'Private', ' Assoc-voc', ' Adm-clerical'),
#  (39, ' State-gov', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Machine-op-inspct'),
#  (39, 'Private', ' Masters', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Exec-managerial'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' Some-college', ' Other-service'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Other-service'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, ' Self-emp-not-inc', ' Some-college', ' Farming-fishing'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, ' Self-emp-not-inc', ' Bachelors', ' Sales'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' HS-grad', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Transport-moving'),
#  (39, 'Private', ' 11th', ' Transport-moving'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, ' Federal-gov', ' Bachelors', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, ' Federal-gov', ' HS-grad', ' Adm-clerical'),
#  (39, ' Self-emp-not-inc', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' 11th', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Other-service'),
#  (39, ' ?', ' 11th', ' ?'),
#  (39, 'Private', ' 12th', ' Transport-moving'),
#  (39, ' Self-emp-inc', ' Assoc-voc', ' Farming-fishing'),
#  (39, ' Self-emp-inc', ' Bachelors', ' Prof-specialty'),
#  (39, ' Self-emp-inc', ' Prof-school', ' Prof-specialty'),
#  (39, 'Private', ' Masters', ' Prof-specialty'),
#  (39, ' Self-emp-inc', ' Masters', ' Prof-specialty'),
#  (39, ' Self-emp-not-inc', ' Bachelors', ' Prof-specialty'),
#  (39, ' Self-emp-inc', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' Assoc-voc', ' Farming-fishing'),
#  (39, 'Private', ' Assoc-acdm', ' Sales'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, ' Federal-gov', ' HS-grad', ' Armed-Forces'),
#  (39, 'Private', ' Some-college', ' Exec-managerial'),
#  (39, ' State-gov', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Other-service'),
#  (39, ' State-gov', ' Masters', ' Prof-specialty'),
#  (39, ' Federal-gov', ' Bachelors', ' Tech-support'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, ' Self-emp-not-inc', ' Masters', ' Craft-repair'),
#  (39, ' Self-emp-inc', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' 12th', ' Transport-moving'),
#  (39, 'Private', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Transport-moving'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Farming-fishing'),
#  (39, ' Federal-gov', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Other-service'),
#  (39, 'Private', ' 7th-8th', ' Transport-moving'),
#  (39, 'Private', ' Prof-school', ' Exec-managerial'),
#  (39, ' Federal-gov', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, ' Self-emp-inc', ' Bachelors', ' Sales'),
#  (39, 'Private', ' 10th', ' Machine-op-inspct'),
#  (39, 'Private', ' Assoc-voc', ' Craft-repair'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' Assoc-voc', ' Tech-support'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Sales'),
#  (39, 'Private', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Handlers-cleaners'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' Some-college', ' Handlers-cleaners'),
#  (39, 'Private', ' Masters', ' Sales'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, ' Self-emp-not-inc', ' Prof-school', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, ' Self-emp-not-inc', ' Doctorate', ' Adm-clerical'),
#  (39, 'Private', ' Assoc-acdm', ' Machine-op-inspct'),
#  (39, 'Private', ' Some-college', ' Sales'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, ' Local-gov', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, ' Self-emp-not-inc', ' 11th', ' Transport-moving'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' Some-college', ' Machine-op-inspct'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' Some-college', ' Exec-managerial'),
#  (39, 'Private', ' Some-college', ' Machine-op-inspct'),
#  (39, ' Local-gov', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' Some-college', ' Craft-repair'),
#  (39, ' Local-gov', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Tech-support'),
#  (39, ' Self-emp-not-inc', ' Doctorate', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Adm-clerical'),
#  (39, 'Private', ' Some-college', ' Craft-repair'),
#  (39, ' Self-emp-inc', ' HS-grad', ' Craft-repair'),
#  (39, ' Federal-gov', ' Assoc-voc', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, ' State-gov', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' Masters', ' Sales'),
#  (39, ' Self-emp-inc', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' 10th', ' Handlers-cleaners'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' Some-college', ' Handlers-cleaners'),
#  (39, ' Self-emp-not-inc', ' Prof-school', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Handlers-cleaners'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Handlers-cleaners'),
#  (39, ' Self-emp-not-inc', ' Some-college', ' Other-service'),
#  (39, 'Private', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' Assoc-acdm', ' Exec-managerial'),
#  (39, 'Private', ' Some-college', ' Other-service'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' Assoc-acdm', ' Other-service'),
#  (39, ' Local-gov', ' Some-college', ' Adm-clerical'),
#  (39, ' Local-gov', ' Masters', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Transport-moving'),
#  (39, 'Private', ' Prof-school', ' Prof-specialty'),
#  (39, ' Federal-gov', ' Some-college', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' Assoc-acdm', ' Craft-repair'),
#  (39, ' State-gov', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' Some-college', ' Other-service'),
#  (39, 'Private', ' Some-college', ' Exec-managerial'),
#  (39, ' Federal-gov', ' HS-grad', ' Craft-repair'),
#  (39, ' State-gov', ' Some-college', ' Protective-serv'),
#  (39, 'Private', ' Prof-school', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, ' Self-emp-inc', ' Bachelors', ' Sales'),
#  (39, 'Private', ' 9th', ' Craft-repair'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Transport-moving'),
#  (39, ' Self-emp-not-inc', ' Some-college', ' Farming-fishing'),
#  (39, 'Private', ' Some-college', ' Machine-op-inspct'),
#  (39, 'Private', ' Doctorate', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Other-service'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' 10th', ' Other-service'),
#  (39, 'Private', ' Some-college', ' Sales'),
#  (39, 'Private', ' HS-grad', ' Handlers-cleaners'),
#  (39, 'Private', ' HS-grad', ' Handlers-cleaners'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Tech-support'),
#  (39, 'Private', ' Masters', ' Adm-clerical'),
#  (39, ' Self-emp-not-inc', ' Bachelors', ' Sales'),
#  (39, 'Private', ' Bachelors', ' Craft-repair'),
#  (39, ' Self-emp-inc', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Tech-support'),
#  (39, ' Self-emp-inc', ' Some-college', ' Craft-repair'),
#  (39, ' Self-emp-inc', ' HS-grad', ' Exec-managerial'),
#  (39, ' Local-gov', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' Some-college', ' Sales'),
#  (39, 'Private', ' 11th', ' Other-service'),
#  (39, 'Private', ' 10th', ' Craft-repair'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Sales'),
#  (39, 'Private', ' HS-grad', ' Transport-moving'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' 10th', ' Transport-moving'),
#  (39, 'Private', ' Assoc-voc', ' Other-service'),
#  (39, 'Private', ' 7th-8th', ' Other-service'),
#  (39, 'Private', ' Prof-school', ' Craft-repair'),
#  (39, 'Private', ' Some-college', ' Machine-op-inspct'),
#  (39, ' Local-gov', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, ' Local-gov', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Transport-moving'),
#  (39, 'Private', ' 5th-6th', ' Other-service'),
#  (39, 'Private', ' Prof-school', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Protective-serv'),
#  (39, 'Private', ' Assoc-acdm', ' Tech-support'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' 12th', ' Machine-op-inspct'),
#  (39, 'Private', ' Some-college', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' Assoc-acdm', ' Other-service'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' Some-college', ' Farming-fishing'),
#  (39, 'Private', ' 9th', ' Handlers-cleaners'),
#  (39, 'Private', ' Assoc-voc', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Transport-moving'),
#  (39, 'Private', ' HS-grad', ' Sales'),
#  (39, ' Federal-gov', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' Masters', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, ' Local-gov', ' Assoc-acdm', ' Other-service'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Farming-fishing'),
#  (39, 'Private', ' 5th-6th', ' Other-service'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, ' Local-gov', ' Some-college', ' Protective-serv'),
#  (39, 'Private', ' 12th', ' Adm-clerical'),
#  (39, 'Private', ' 10th', ' Machine-op-inspct'),
#  (39, 'Private', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Sales'),
#  (39, 'Private', ' Assoc-voc', ' Exec-managerial'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Farming-fishing'),
#  (39, 'Private', ' Masters', ' Prof-specialty'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' Some-college', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, ' State-gov', ' Masters', ' Prof-specialty'),
#  (39, ' Self-emp-inc', ' Assoc-voc', ' Craft-repair'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, ' Local-gov', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Craft-repair'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' Masters', ' Exec-managerial'),
#  (39, 'Private', ' Assoc-voc', ' Machine-op-inspct'),
#  (39, 'Private', ' Some-college', ' Other-service'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' Prof-school', ' Sales'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Craft-repair'),
#  (39, ' Self-emp-inc', ' Masters', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Transport-moving'),
#  (39, ' Self-emp-not-inc', ' Some-college', ' Sales'),
#  (39, ' Self-emp-inc', ' Assoc-voc', ' Exec-managerial'),
#  (39, 'Private', ' Some-college', ' Prof-specialty'),
#  (39, ' Local-gov', ' Assoc-acdm', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, ' Local-gov', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' Bachelors', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Other-service'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Farming-fishing'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Prof-school', ' Exec-managerial'),
#  (39, ' State-gov', ' Some-college', ' Transport-moving'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' Prof-school', ' Exec-managerial'),
#  (39, 'Private', ' Assoc-acdm', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Transport-moving'),
#  (39, 'Private', ' Assoc-voc', ' Craft-repair'),
#  (39, 'Private', ' Some-college', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Exec-managerial'),
#  (39, ' State-gov', ' Assoc-acdm', ' Prof-specialty'),
#  (39, ' Self-emp-not-inc', ' Some-college', ' Sales'),
#  (39, 'Private', ' HS-grad', ' Farming-fishing'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, ' Local-gov', ' Some-college', ' Protective-serv'),
#  (39, 'Private', ' 7th-8th', ' Machine-op-inspct'),
#  (39, ' Local-gov', ' HS-grad', ' Machine-op-inspct'),
#  (39, ' Self-emp-not-inc', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, ' State-gov', ' Some-college', ' Prof-specialty'),
#  (39, 'Private', ' Prof-school', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' Assoc-voc', ' Craft-repair'),
#  (39, ' State-gov', ' HS-grad', ' Adm-clerical'),
#  (39, ' Local-gov', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Machine-op-inspct'),
#  (39, 'Private', ' HS-grad', ' Sales'),
#  (39, ' Self-emp-inc', ' Masters', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, 'Private', ' Assoc-voc', ' Tech-support'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' Some-college', ' Other-service'),
#  (39, ' State-gov', ' Doctorate', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Exec-managerial'),
#  (39, 'Private', ' Some-college', ' Sales'),
#  (39, 'Private', ' HS-grad', ' Other-service'),
#  (39, 'Private', ' HS-grad', ' Sales'),
#  (39, 'Private', ' Some-college', ' Machine-op-inspct'),
#  (39, 'Private', ' Bachelors', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Prof-specialty'),
#  (39, 'Private', ' Assoc-acdm', ' Protective-serv'),
#  (39, ' Local-gov', ' Assoc-acdm', ' Transport-moving'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, 'Private', ' 9th', ' Handlers-cleaners'),
#  (39, 'Private', ' HS-grad', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Machine-op-inspct'),
#  (39, 'Private', ' Some-college', ' Craft-repair'),
#  (39, 'Private', ' Some-college', ' Machine-op-inspct'),
#  (39, ' Local-gov', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' Some-college', ' Sales'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' 11th', ' Sales'),
#  (39, 'Private', ' HS-grad', ' Handlers-cleaners'),
#  (39, 'Private', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' 11th', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' Some-college', ' Prof-specialty'),
#  (39, ' Local-gov', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' Masters', ' Other-service'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, ' Local-gov', ' Masters', ' Prof-specialty'),
#  (39, ' Local-gov', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, ' Self-emp-not-inc', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Adm-clerical'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, ' State-gov', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Craft-repair'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Machine-op-inspct'),
#  (39, ' Self-emp-not-inc', ' Prof-school', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' Some-college', ' Other-service'),
#  (39, 'Private', ' Assoc-voc', ' Craft-repair'),
#  (39, 'Private', ' Assoc-acdm', ' Adm-clerical'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' HS-grad', ' Prof-specialty'),
#  (39, 'Private', ' Assoc-acdm', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' Assoc-acdm', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' HS-grad', ' Handlers-cleaners'),
#  (39, 'Private', ' Some-college', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Sales'),
#  (39, ' Local-gov', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' Masters', ' Prof-specialty'),
#  (39, ' State-gov', ' HS-grad', ' Prof-specialty'),
#  (39, ' Local-gov', ' HS-grad', ' Handlers-cleaners'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, ' State-gov', ' 11th', ' Craft-repair'),
#  (39, ' Self-emp-inc', ' Assoc-acdm', ' Sales'),
#  (39, ' Self-emp-inc', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Transport-moving'),
#  (39, 'Private', ' 5th-6th', ' Other-service'),
#  (39, 'Private', ' Masters', ' Exec-managerial'),
#  (39, ' Self-emp-not-inc', ' Some-college', ' Farming-fishing'),
#  (39, 'Private', ' Assoc-voc', ' Machine-op-inspct'),
#  (39, 'Private', ' Assoc-acdm', ' Tech-support'),
#  (39, 'Private', ' Assoc-acdm', ' Adm-clerical'),
#  (39, ' ?', ' HS-grad', ' ?'),
#  (39, 'Private', ' Bachelors', ' Adm-clerical'),
#  (39, 'Private', ' 12th', ' Handlers-cleaners'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, ' ?', ' Some-college', ' ?'),
#  (39, ' Federal-gov', ' Assoc-acdm', ' Prof-specialty'),
#  (39, 'Private', ' Some-college', ' Craft-repair'),
#  (39, 'Private', ' 11th', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, ' State-gov', ' HS-grad', ' Other-service'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Farming-fishing'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' Doctorate', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' Some-college', ' Other-service'),
#  (39, 'Private', ' Some-college', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Other-service'),
#  (39, ' Federal-gov', ' 9th', ' Machine-op-inspct'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, ' State-gov', ' Some-college', ' Adm-clerical'),
#  (39, ' Federal-gov', ' Prof-school', ' Prof-specialty'),
#  (39, 'Private', ' Assoc-voc', ' Sales'),
#  (39, ' State-gov', ' Bachelors', ' Exec-managerial'),
#  (39, ' State-gov', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Other-service'),
#  (39, 'Private', ' Bachelors', ' Adm-clerical'),
#  (39, 'Private', ' Some-college', ' Exec-managerial'),
#  (39, 'Private', ' Doctorate', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Farming-fishing'),
#  (39, ' Federal-gov', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' Some-college', ' Exec-managerial'),
#  (39, 'Private', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, ' Self-emp-not-inc', ' Bachelors', ' Farming-fishing'),
#  (39, 'Private', ' HS-grad', ' Handlers-cleaners'),
#  (39, ' Federal-gov', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Farming-fishing'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Farming-fishing'),
#  (39, 'Private', ' Assoc-acdm', ' Tech-support'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' Assoc-acdm', ' Exec-managerial'),
#  (39, 'Private', ' 11th', ' Craft-repair'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, ' State-gov', ' Assoc-voc', ' Exec-managerial'),
#  (39, 'Private', ' Some-college', ' Craft-repair'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Sales'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, ' Local-gov', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Assoc-voc', ' Other-service'),
#  (39, 'Private', ' Some-college', ' Exec-managerial'),
#  (39, ' Federal-gov', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' Some-college', ' Machine-op-inspct'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, ' Self-emp-not-inc', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, ' Federal-gov', ' Some-college', ' Exec-managerial'),
#  (39, ' ?', ' 12th', ' ?'),
#  (39, 'Private', ' HS-grad', ' Transport-moving'),
#  (39, 'Private', ' HS-grad', ' Transport-moving'),
#  (39, 'Private', ' 9th', ' Craft-repair'),
#  (39, 'Private', ' Bachelors', ' Sales'),
#  (39, 'Private', ' Assoc-acdm', ' Exec-managerial'),
#  (39, 'Private', ' Some-college', ' Sales'),
#  (39, 'Private', ' Masters', ' Exec-managerial'),
#  (39, 'Private', ' Masters', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Adm-clerical'),
#  (39, ' Self-emp-not-inc', ' 9th', ' Farming-fishing'),
#  (39, 'Private', ' 7th-8th', ' Other-service'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Sales'),
#  (39, 'Private', ' Some-college', ' Exec-managerial'),
#  (39, 'Private', ' Bachelors', ' Adm-clerical'),
#  (39, 'Private', ' 10th', ' Craft-repair'),
#  (39, 'Private', ' 10th', ' Machine-op-inspct'),
#  (39, 'Private', ' HS-grad', ' Sales'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Craft-repair'),
#  (39, ' Local-gov', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' Assoc-voc', ' Craft-repair'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, 'Private', ' Bachelors', ' Tech-support'),
#  (39, 'Private', ' Bachelors', ' Prof-specialty'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Transport-moving'),
#  (39, ' Federal-gov', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' Bachelors', ' Adm-clerical'),
#  (39, 'Private', ' 10th', ' Other-service'),
#  (39, 'Private', ' Masters', ' Prof-specialty'),
#  (39, 'Private', ' HS-grad', ' Handlers-cleaners'),
#  (39, 'Private', ' Some-college', ' Machine-op-inspct'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, 'Private', ' 11th', ' Transport-moving'),
#  (39, 'Private', ' Some-college', ' Exec-managerial'),
#  (39, 'Private', ' 9th', ' Handlers-cleaners'),
#  (39, 'Private', ' HS-grad', ' Adm-clerical'),
#  (39, ' Local-gov', ' Assoc-voc', ' Adm-clerical'),
#  (39, 'Private', ' Bachelors', ' Tech-support'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' Assoc-voc', ' Craft-repair'),
#  (39, 'Private', ' HS-grad', ' Machine-op-inspct'),
#  (39, 'Private', ' Bachelors', ' Exec-managerial'),
#  (39, 'Private', ' Some-college', ' Craft-repair'),
#  (39, 'Private', ' Some-college', ' Transport-moving'),
#  (39, ' Federal-gov', ' Some-college', ' Adm-clerical'),
#  (39, 'Private', ' HS-grad', ' Other-service'),
#  (39, ' Federal-gov', ' Bachelors', ' Adm-clerical'),
#  (39, ' Self-emp-not-inc', ' HS-grad', ' Exec-managerial'),
#  (39, 'Private', ' HS-grad', ' Prof-specialty'),
#  (39, ' Local-gov', ' Assoc-acdm', ' Adm-clerical')]
